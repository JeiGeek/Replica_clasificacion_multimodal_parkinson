# %% [markdown]
# # **Carga de datos**

# %%
# Carga del dataset desde github
url = "https://raw.githubusercontent.com/JeiGeek/Replica_clasificacion_multimodal_parkinson/main/requirements/MDS-UPDRS_Part_III_28Oct2025_estandarizado_pd_mbrs.csv"
df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-545/483104205.py in <cell line: 0>()
#       1 # Carga del dataset desde github
#       2 url = "https://raw.githubusercontent.com/JeiGeek/Replica_clasificacion_multimodal_parkinson/main/requirements/MDS-UPDRS_Part_III_28Oct2025_estandarizado_pd_mbrs.csv"
# ----> 3 df = pd.read_csv(url)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # **Análisis exploratorio**

# %% [markdown]
# # **Preprocesamiento**

# %% [markdown]
# # **Generación de prompts**

# %% [markdown]
# # **Extracción de embeddings**

# %% [markdown]
# # **Experimentación**
